# %% [markdown]
# <a href="https://colab.research.google.com/github/komalvirk1801/DATA_ANALYST_PORTFOLIO/blob/main/DataAnalysisOnBrainStrokeData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BRAIN STROKE DATASET

# %% [markdown]
# A **stroke** is a medical condition in which poor blood flow to the brain causes cell death. There are two main types of stroke: **ischemic**, due to lack of blood flow, and **hemorrhagic**, due to bleeding. Both cause parts of the brain to stop functioning properly.
# Signs and symptoms of a stroke may include an inability to move or feel on one side of the body, problems understanding or speaking, dizziness, or loss of vision to one side. Signs and symptoms often appear soon after the stroke has occurred. If symptoms last less than one or two hours, the stroke is a transient ischemic attack (TIA), also called a mini-stroke. A hemorrhagic stroke may also be associated with a severe headache. The symptoms of a stroke can be permanent. Long-term complications may include pneumonia and loss of bladder control.

# %% [markdown]
# The main risk factor for stroke is high blood pressure. Other risk factors include high blood cholesterol, tobacco smoking, obesity, diabetes mellitus, a previous TIA, end-stage kidney disease, and atrial fibrillation. An ischemic stroke is typically caused by blockage of a blood vessel, though there are also less common causes. A hemorrhagic stroke is caused by either bleeding directly into the brain or into the space between the brain's membranes. Bleeding may occur due to a ruptured brain aneurysm. Diagnosis is typically based on a physical exam and is supported by medical imaging such as a CT scan or MRI scan. A CT scan can rule out bleeding, but may not necessarily rule out ischemia, which early on typically does not show up on a CT scan. Other tests such as an electrocardiogram (ECG) and blood tests are done to determine risk factors and rule out other possible causes. Low blood sugar may cause similar symptoms.
# Prevention includes decreasing risk factors, surgery to open up the arteries to the brain in those with problematic carotid narrowing, and warfarin in people with atrial fibrillation. Aspirin or statins may be recommended by physicians for prevention. A stroke or TIA often requires emergency care. An ischemic stroke, if detected within three to four and half hours, may be treatable with a medication that can break down the clot. Some hemorrhagic strokes benefit from surgery. Treatment to attempt recovery of lost function is called stroke rehabilitation, and ideally takes place in a stroke unit; however, these are not available in much of the world.

# %% [markdown]
# ## *ABOUT THE DATA*

# %% [markdown]
# FEATURE INFORMATION
#
# 1) gender: "Male", "Female" or "Other"
#
# 2) age: age of the patient
#
# 3) hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
#
# 4) heart disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease 5) Ever-married: "No" or "Yes"
#
# 6) work type: "children", "Govtjov", "Never worked", "Private" or "Self-employed"
#
# 7) Residencetype: "Rural" or "Urban"
#
# 8) avg glucose level: average glucose level in blood
#
# 9) BMI: body mass index
#
# 10) smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*
#
# 11) stroke: 1 if the patient had a stroke or 0 if not

# %%
# load the data

import numpy as np # linear algebra
import pandas as pd # read and load dataset

# %%
dataset=pd.read_csv("brain_stroke.csv")
dataset
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
dataset.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
dataset.describe(include = 'all')
# Out:
#         gender          age  hypertension  heart_disease ever_married  \
# count     4981  4981.000000   4981.000000    4981.000000         4981
# unique       2          NaN           NaN            NaN            2
# top     Female          NaN           NaN            NaN          Yes
# freq      2907          NaN           NaN            NaN         3280
# mean       NaN    43.419859      0.096165       0.055210          NaN
# std        NaN    22.662755      0.294848       0.228412          NaN
# min        NaN     0.080000      0.000000       0.000000          NaN
# 25%        NaN    25.000000      0.000000       0.000000          NaN
# 50%        NaN    45.000000      0.000000       0.000000          NaN
# 75%        NaN    61.000000      0.000000       0.000000          NaN
# max        NaN    82.000000      1.000000       1.000000          NaN
#
#        work_type Residence_type  avg_glucose_level          bmi  \
# ...

# %% [markdown]
# **UNDERSTANDING THE DATASET**

# %% [markdown]
# **Gender Distribution:** There is a higher number of female participants compared to males.
# **Age:** The age distribution is wide, ranging from infants (0.08 years) to elderly individuals (82 years), with an average age of about 43 years.
# **Health Conditions:** Hypertension and heart disease are relatively low in the dataset, with mean incidences of 9.62% and 5.52%, respectively.
# **Marital and Work Status:** The majority of individuals are married and work in the private sector.
# **Residence:** Urban residents constitute the majority of the dataset.
# **Health Metrics:** Average glucose levels and BMI indicate a diverse range of health profiles.
# **Smoking Status:** A significant portion of the dataset consists of individuals who have never smoked.
# **Stroke Incidence:** The dataset has a low incidence of stroke occurrences.
# This summary provides a high-level overview of the dataset, highlighting key features and statistical insights that can be further explored for more detailed analysis and reporting.

# %% [markdown]
# ***Problem Statement:***
#
# Brainstroke, a leading cause of disability and death globally, presents a significant challenge in medical research and healthcare. Despite advances in medical technology, predicting and understanding the factors contributing to brainstroke remain complex and crucial for improving patient outcomes.
#
# The objective of this analysis is to examine a comprehensive brainstroke dataset to identify key patterns and factors associated with the incidence of brainstroke. The dataset includes various patient attributes such as demographic information, medical history, lifestyle factors, and clinical measurements.
#
# ***Key Questions to Address:***
#
# **What are the primary risk factors associated with brainstroke?**
# Analyze the dataset to identify and quantify the impact of different risk factors such as age, gender, hypertension, diabetes, smoking, and physical inactivity on the likelihood of brainstroke.
#
#
# **How do different factors interact to influence brainstroke risk?**
# Explore interactions between various factors to understand their combined effects on brainstroke risk and uncover any significant correlations or patterns.
#
# **What insights can be derived to support clinical decision-making and public health strategies?**
# Generate actionable insights from the data that can inform healthcare professionals and policymakers in designing effective prevention and intervention strategies for brainstroke.
#
# ***Scope:***
#
# The analysis will focus on data preprocessing, exploratory data analysis, feature selection, and the application of statistical and machine learning techniques to uncover meaningful insights. The ultimate goal is to contribute valuable knowledge that can support efforts in reducing brainstroke incidence and improving patient care.

# %% [markdown]
# **Let's create some hist charts to better understand the dataset relationship**

# %%
sns.histplot(data=dataset["age"],kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# The above histogram shows the distribution of ages in the dataset. It appears to be a right-skewed distribution, indicating a higher concentration of younger individuals in the dataset. The kernel density estimate (kde) line provides a smoothed representation of the distribution.

# %%
sns.histplot(data=dataset["bmi"],kde=True)

plt.show()

# %% [markdown]
# The histogram for BMI shows a distribution that is slightly skewed to the right. This indicates that the majority of individuals in the dataset have BMIs in the normal to slightly overweight range. However, there is a tail extending towards higher BMI values, suggesting the presence of some individuals with higher BMIs in the dataset.

# %%
sns.histplot(data=dataset["avg_glucose_level"],kde=True)

plt.show()

# %% [markdown]
# The histogram for average glucose level exhibits a right-skewed distribution. This suggests that the majority of individuals in the dataset have average glucose levels within a relatively normal range. However, there is a noticeable tail extending towards higher glucose values, indicating the presence of some individuals with elevated glucose levels, potentially indicating a risk of diabetes or other related conditions.

# %% [markdown]
# **Data Label Encoding**
# Using label encoding to tranform the categorical data or textual data into the numerical values so that it is easier for analysing and modeling the data.

# %%
from sklearn.preprocessing import LabelEncoder
lbl=LabelEncoder()

# %%
dataset["gender"]=lbl.fit_transform(dataset['gender'])
dataset["ever_married"]=lbl.fit_transform(dataset['ever_married'])
dataset["work_type"]=lbl.fit_transform(dataset['work_type'])
dataset["Residence_type"]=lbl.fit_transform(dataset['Residence_type'])
dataset["smoking_status"]=lbl.fit_transform(dataset['smoking_status'])

# %%
dataset
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          1
# 1          1  80.0             0              1             1          1
# 2          0  49.0             0              0             1          1
# 3          0  79.0             1              0             1          2
# 4          1  81.0             0              0             1          1
# ...      ...   ...           ...            ...           ...        ...
# 4976       1  41.0             0              0             0          1
# 4977       1  40.0             0              0             1          1
# 4978       0  45.0             1              0             1          0
# 4979       1  40.0             0              0             1          1
# 4980       0  80.0             1              0             1          1
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
dataset.corr() #relation between the variables.
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000 -0.026538      0.021485       0.086476
# age               -0.026538  1.000000      0.278120       0.264852
# hypertension       0.021485  0.278120      1.000000       0.111974
# heart_disease      0.086476  0.264852      0.111974       1.000000
# ever_married      -0.028971  0.677137      0.164534       0.114765
# work_type          0.065784 -0.415935     -0.061618      -0.036943
# Residence_type    -0.004301  0.017155     -0.004755       0.002125
# avg_glucose_level  0.055796  0.236763      0.170028       0.166847
# bmi               -0.012093  0.373703      0.158762       0.060926
# smoking_status    -0.062666  0.265623      0.110045       0.048093
# stroke             0.008870  0.246478      0.131965       0.134610
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                -0.028971   0.065784       -0.004301           0.055796
# ...

# %%
# correlation using the heatmap
import seaborn as sns
import matplotlib.pyplot as plt
# plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
# sns.heatmap(data=dataset.corr(),annot=True)
# plt.show()

# Create a correlation matrix for visualization
corr_matrix = dataset.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
#  The heatmap shows the correlation between different features in the dataset.
# Positive values indicate a positive correlation, while negative values indicate a negative correlation.
# Values closer to 1 or -1 indicate a stronger correlation, while values closer to 0 indicate a weaker correlation.
#
# **Some observations from the heatmap:**
#
# * Age and hypertension have a moderate positive correlation, suggesting that older individuals are more likely to have hypertension.
# * Age and stroke have a moderate positive correlation, suggesting that older individuals are more likely to have a stroke.
# * BMI and avg_glucose_level have a weak positive correlation, suggesting that individuals with higher BMI tend to have slightly higher average glucose levels.
# * Smoking status and stroke have a weak positive correlation, suggesting that smokers may be slightly more likely to have a stroke.
#
# These are just a few observations, and further analysis is needed to draw definitive conclusions.
# The heatmap provides a visual representation of the relationships between features, which can be helpful for identifying potential predictors of stroke.

# %%
# Extract correlation with stroke
correlations = dataset.corr()['stroke'].sort_values(ascending=False)

# Plot the bar chart
plt.figure(figsize=(10, 6))
correlations.drop('stroke').plot(kind='bar')
plt.title('Correlation of Factors with Stroke')
plt.xlabel('Factors')
plt.ylabel('Correlation Coefficient')
plt.xticks(rotation=45)
plt.show()

# %%
# Pair plot of factors with stroke
sns.pairplot(dataset, hue='stroke', vars=['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi'])
plt.show()

# %% [markdown]
# The pairplot visualizes the relationship between pairs of variables in the dataset, with the points colored based on whether the individual had a stroke (stroke=1) or not (stroke=0).
#
# **Key observations:**
#
# - Age vs. Other Factors: Higher age shows a greater concentration of stroke cases across all other factors (hypertension, heart disease, avg_glucose_level, bmi).
# - Hypertension: Individuals with hypertension tend to have a higher likelihood of stroke, especially when combined with older age.
# - Heart Disease: Similar to hypertension, the presence of heart disease increases the risk of stroke, particularly in older individuals.
# - Avg Glucose Level: Higher average glucose levels show a slight increase in stroke occurrences, but the relationship is less pronounced compared to age, hypertension, and heart disease.
# - BMI: The impact of BMI on stroke risk appears less clear from the pairplot. There might be a slight increase in stroke cases with higher BMI, but further analysis is needed.

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dataset[dataset['stroke'] == 0]['age'], dataset[dataset['stroke'] == 0]['avg_glucose_level'], label='No Stroke', alpha=0.5)
plt.scatter(dataset[dataset['stroke'] == 1]['age'], dataset[dataset['stroke'] == 1]['avg_glucose_level'], label='Stroke', alpha=0.5)
plt.title('AGE vs.AVG_GLUCOSE_LEVEL and Stroke Occurrence')
plt.xlabel('AGE')
plt.ylabel('AVG_GLUCOSE_LEVEL')
plt.legend()
plt.show()

# %% [markdown]
# **Key observations:**
#
# - Age and Glucose Level: There is a general trend of increasing average glucose levels with age, regardless of stroke occurrence.
# - Stroke Occurrence: Individuals who experienced a stroke (orange dots) tend to be concentrated in the higher age and higher average glucose level regions of the plot.
# - Overlap: There is considerable overlap between the two groups (stroke and no stroke), indicating that age and average glucose level alone are not sufficient to perfectly predict stroke occurrence. Other factors likely play a significant role.
#
# This plot suggests that older individuals with higher average glucose levels might be at an increased risk of stroke. However, further analysis is needed to confirm this relationship and identify other contributing factors.

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dataset[dataset['stroke'] == 0]['age'], dataset[dataset['stroke'] == 0]['bmi'], label='No Stroke', alpha=0.5)
plt.scatter(dataset[dataset['stroke'] == 1]['age'], dataset[dataset['stroke'] == 1]['bmi'], label='Stroke', alpha=0.5)
plt.title('Age vs. BMI and Stroke Occurrence')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.legend()
plt.show()

# %% [markdown]
# **Key observations:**
#
# - Age and BMI: There is a general trend of increasing BMI with age, particularly up to around 60 years old, regardless of stroke occurrence.
# - Stroke Occurrence: Individuals who experienced a stroke (orange dots) tend to be concentrated in the higher age range, with a wider distribution of BMI values.
# - Overlap: There is significant overlap between the two groups (stroke and no stroke), suggesting that age and BMI alone are not strong predictors of stroke occurrence. Other factors likely play a crucial role.
#
# This plot indicates that while older individuals might be at a higher risk of stroke, BMI might not be a strong independent predictor. Further analysis, including other factors and potentially non-linear relationships, is necessary to gain a more comprehensive understanding of stroke risk.

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dataset[dataset['stroke'] == 0]['bmi'], dataset[dataset['stroke'] == 0]['avg_glucose_level'], label='No Stroke', alpha=0.5)
plt.scatter(dataset[dataset['stroke'] == 1]['bmi'], dataset[dataset['stroke'] == 1]['avg_glucose_level'], label='Stroke', alpha=0.5)
plt.title('BMI vs.AVG_GLUCOSE_LEVEL and Stroke Occurrence')
plt.xlabel('BMI')
plt.ylabel('AVG_GLUCOSE_LEVEL')
plt.legend()
plt.show()

# %% [markdown]
#  **Key observations from the scatter plot of BMI vs. Average Glucose Level and Stroke Occurrence:**
#
# - Distribution: Both individuals with and without stroke exhibit a wide range of BMI and average glucose levels.
# - Stroke Occurrence: There is a slight tendency for individuals who experienced a stroke (orange dots) to have higher average glucose levels, particularly in the mid-range of BMI values.
# - Overlap: There is significant overlap between the two groups (stroke and no stroke), indicating that BMI and average glucose level alone are not strong predictors of stroke occurrence. Other factors likely play a crucial role.
#
# This plot suggests a potential association between higher average glucose levels and stroke risk, especially for individuals with moderate to high BMI. However, the relationship is not clear-cut, and further analysis is needed to determine the independent contribution of these factors and identify other potential risk factors.

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dataset[dataset['stroke'] == 0]['hypertension'], dataset[dataset['stroke'] == 0]['avg_glucose_level'], label='No Stroke', alpha=0.5)
plt.scatter(dataset[dataset['stroke'] == 1]['hypertension'], dataset[dataset['stroke'] == 1]['avg_glucose_level'], label='Stroke', alpha=0.5)
plt.title('hypertension vs.AVG_GLUCOSE_LEVEL and Stroke Occurrence')
plt.xlabel('hypertension')
plt.ylabel('AVG_GLUCOSE_LEVEL')
plt.legend()
plt.show()

# %% [markdown]
#  **Key observations from the scatter plot of Hypertension vs. Average Glucose Level and Stroke Occurrence:**
#
# - Hypertension and Glucose Level: Individuals with hypertension (value 1 on the x-axis) tend to have a wider range of average glucose levels compared to those without hypertension (value 0).
# - Stroke Occurrence: There is a noticeable concentration of stroke cases (orange dots) among individuals with hypertension and higher average glucose levels.
# - No Hypertension: Among individuals without hypertension, stroke occurrences are relatively rare, regardless of average glucose level.
#
# This plot suggests a potential interaction between hypertension and average glucose level in influencing stroke risk. Individuals with both hypertension and elevated average glucose levels might be at a significantly higher risk of stroke compared to those with only one or neither of these conditions. However, further analysis is needed to confirm this interaction and quantify the associated risk.

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dataset[dataset['stroke'] == 0]['heart_disease'], dataset[dataset['stroke'] == 0]['avg_glucose_level'], label='No Stroke', alpha=0.5)
plt.scatter(dataset[dataset['stroke'] == 1]['heart_disease'], dataset[dataset['stroke'] == 1]['avg_glucose_level'], label='Stroke', alpha=0.5)
plt.title('heart_disease vs.AVG_GLUCOSE_LEVEL and Stroke Occurrence')
plt.xlabel('heart_disease')
plt.ylabel('AVG_GLUCOSE_LEVEL')
plt.legend()
plt.show()

# %% [markdown]
# **Key observations from the scatter plot of Heart Disease vs. Average Glucose Level and Stroke Occurrence:**
#
# - Heart Disease and Glucose Level: Individuals with heart disease (value 1 on the x-axis) tend to have a wider range of average glucose levels compared to those without heart disease (value 0).
# - Stroke Occurrence: There is a noticeable concentration of stroke cases (orange dots) among individuals with heart disease and higher average glucose levels.
# - No Heart Disease: Among individuals without heart disease, stroke occurrences are relatively rare, regardless of average glucose level.
#
# This plot suggests a potential interaction between heart disease and average glucose level in influencing stroke risk. Individuals with both heart disease and elevated average glucose levels might be at a significantly higher risk of stroke compared to those with only one or neither of these conditions. However, further analysis is needed to confirm this interaction and quantify the associated risk.

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dataset[dataset['stroke'] == 0]['heart_disease'], dataset[dataset['stroke'] == 0]['hypertension'], label='No Stroke', alpha=0.5)
plt.scatter(dataset[dataset['stroke'] == 1]['heart_disease'], dataset[dataset['stroke'] == 1]['hypertension'], label='Stroke', alpha=0.5)
plt.title('heart_disease vs.hypertension and Stroke Occurrence')
plt.xlabel('heart_disease')
plt.ylabel('hypertension')
plt.legend()
plt.show()

# %% [markdown]
# **Key observations from the scatter plot of Heart Disease vs. Hypertension and Stroke Occurrence:**
#
# - Heart Disease and Hypertension: Individuals with both heart disease (value 1 on the x-axis) and hypertension (value 1 on the y-axis) show a higher concentration of stroke cases (orange dots).
# - Individual Conditions: While stroke occurrences are observed in individuals with either heart disease or hypertension alone, the combination of both conditions appears to significantly increase the risk.
# - No Conditions: Individuals with neither heart disease nor hypertension have a very low incidence of stroke.
#
# This plot strongly suggests a synergistic effect between heart disease and hypertension in increasing stroke risk. The presence of both conditions poses a substantially higher risk compared to either condition alone. This highlights the importance of managing both heart disease and hypertension to mitigate stroke risk.
